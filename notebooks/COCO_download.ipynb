# %% [markdown]
# # Mounting onto the Drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os

# %%
# If necessary install the packages

# !pip uninstall -y huggingface_hub transformers datasets pyarrow
# !pip uninstall -y cudf-cu12 pylibcudf-cu12
# !pip install -Uq "huggingface_hub" "transformers" "datasets" "pyarrow"
# Out:
# Found existing installation: huggingface-hub 0.36.0
# Uninstalling huggingface-hub-0.36.0:
#   Successfully uninstalled huggingface-hub-0.36.0
# Found existing installation: transformers 4.57.1
# Uninstalling transformers-4.57.1:
#   Successfully uninstalled transformers-4.57.1
# Found existing installation: datasets 4.3.0
# Uninstalling datasets-4.3.0:
#   Successfully uninstalled datasets-4.3.0
# Found existing installation: pyarrow 22.0.0
# Uninstalling pyarrow-22.0.0:
#   Successfully uninstalled pyarrow-22.0.0
# WARNING: Skipping cudf-cu12 as it is not installed.
# WARNING: Skipping pylibcudf-cu12 as it is not installed.

# %% [markdown]
# # Downloading COCO

# %%
SHARED_DRIVE_PATH = "/content/gdrive/MyDrive/HANDS_ON_GEN_AI/Datasets/COCO"

# %%
# %cd "$SHARED_DRIVE_PATH"

print(f"Changed directory to: {SHARED_DRIVE_PATH}")
print("Downloading files... (This may take several minutes)")

if not os.path.isdir('val2017'):
  # 1. Download Validation set files (Images + Annotations)
  # !wget -qc http://images.cocodataset.org/zips/val2017.zip
  # Unzip
  # !unzip -q val2017.zip -d .
  # !rm val2017.zip

if os.path.isdir('test2017'):
  # 2. Download Test Set Files (Images + Annotations Info)
  # !wget -qc http://images.cocodataset.org/zips/test2017.zip
  #Unzip
  # !unzip -q test2017.zip -d .
  # !rm test2017.zip

if os.path.isdir('annotations'):
  # !wget -qc http://images.cocodataset.org/annotations/annotations_trainval2017.zip
  # !wget -qc http://images.cocodataset.org/annotations/image_info_test2017.zip
  # 3. Unzip all downloaded files
  # !unzip -q annotations_trainval2017.zip -d .
  # !unzip -q image_info_test2017.zip -d .
  # 4. Clean up the zip files to save space
  # !rm annotations_trainval2017.zip
  # !rm image_info_test2017.zip


# 5. List the contents to verify
# !echo "--- Final contents of your folder: ---"
# !ls -F
# Out:
# /content/gdrive/MyDrive/HANDS_ON_GEN_AI/Datasets/COCO
# Changed directory to: /content/gdrive/MyDrive/HANDS_ON_GEN_AI/Datasets/COCO
# ...
# Download complete. Extracting files...
# ✅ Extraction complete. Your dataset is ready.
# --- Final contents of your folder: ---
# annotations/  test2017/  val2017/
